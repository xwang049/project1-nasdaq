# %%
import nasdaqdatalink

# %%
nasdaqdatalink.read_key(filename="mykey")

# %%
nasdaqdatalink.bulkdownload('EOD')
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 nasdaqdatalink.bulkdownload('EOD')
#
# File c:\Users\Administrator\.conda\envs\pj1\lib\site-packages\nasdaq_data_link-1.0.4-py3.8.egg\nasdaqdatalink\bulkdownload.py:24, in bulkdownload(database, **kwargs)
#      21 ApiKeyUtil.init_api_key_from_args(kwargs)
#      23 filename = kwargs.pop('filename', '.')
# ---> 24 return Database(database).bulk_download_to_file(filename, params=kwargs)
#
# File c:\Users\Administrator\.conda\envs\pj1\lib\site-packages\nasdaq_data_link-1.0.4-py3.8.egg\nasdaqdatalink\model\database.py:46, in Database.bulk_download_to_file(self, file_or_folder_path, **options)
#      43 path_url = self._bulk_download_path()
#      45 options['stream'] = True
# ---> 46 r = Connection.request('get', path_url, **options)
#      47 file_path = file_or_folder_path
# ...

# %%
db = nasdaqdatalink.Database('WIKI')
db.datasets()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Administrator\.conda\envs\pj1\lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\Administrator\.conda\envs\pj1\lib\json\__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#
# ...

# %%
nasdaqdatalink.Database.all()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Administrator\.conda\envs\pj1\lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\Administrator\.conda\envs\pj1\lib\json\__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#
# ...
