# %%
import nasdaqdatalink as nd
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, Float, String, inspect
from sqlalchemy.exc import SQLAlchemyError
import pandas as pd
import os
import gzip
import shutil
from concurrent.futures import ThreadPoolExecutor, as_completed
import logging
import time
from dotenv import load_dotenv
import pickle
logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)
load_dotenv()
# Out:
# True

# %%
NASDAQ_API = os.environ.get('NASDAQ_API')
nd.ApiConfig.api_key = NASDAQ_API

# %%
MYSQL_HOST = os.getenv("MYSQL_HOST")
MYSQL_USER = os.getenv("MYSQL_USER")
MYSQL_PASSWORD = os.getenv("MYSQL_PASSWORD")
MYSQL_DB = os.getenv("MYSQL_DB")


DATABASE_URL = f"mysql+mysqlconnector://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOST}/{MYSQL_DB}"
engine = create_engine(DATABASE_URL)

# %%
MYSQL_DB
# Out:
# 'nasdaqdata'

# %%
def save_to_csv(dataframe, file_path):
    dataframe.to_csv(file_path, index=False)

def compress_file(file_path):
    with open(file_path, 'rb') as f_in:
        with gzip.open(file_path + '.gz', 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)
    os.remove(file_path)



def download_data(table, **filters):
    try:
        data = nd.get_table(table, **filters)
        return table, data
    except Exception as e:
        print(f"Error downloading data for {table}: {str(e)}")
        return table, None

def save_to_db(dataframe, table_name, engine):
    try:
        # metadata = MetaData()
        # metadata.reflect(bind=engine)
        table_name = table_name.replace('/', '_').lower()
        dataframe.to_sql(table_name, engine, if_exists='replace', index=False)
        print(f"Data saved to {table_name} table successfully.")
    except SQLAlchemyError as e:
        print(f"Error saving {table_name}: {str(e)}")

# @task(retries=3)
def process_data(key):
    try:
        df = nd.get_table(key).head()
        date_guess = [col for col in df.columns if 'date' in col.lower()][0]
        table, data = download_data(key, paginate = True,  **{date_guess: {'gte': '2024-03-15'}})
        save_to_db(data, key)
    except:
        table, data = download_data(key, paginate = True)
        save_to_db(data, key)

# %%
tables_filters = {
    # 'QDL/ODA': {},
    # 'QDL/FON': {},
    # 'QDL/OPEC': {},
    # 'QDL/JODI': {},
    # 'QDL/BITFINEX': {},
    # 'QDL/BCHAIN': {},
    # 'QDL/LME': {},
    # 'ZILLOW/DATA': {},
    # 'WASDE/DATA': {},
    # 'WB/DATA': {}
    'DY/FDEQU' :{}
}
# filters = {
#     # 'date': '2019-10-08', 
#     # 'contract_code': '967654'
# }
# data = download_data(table, **filters)

# %%
# data.head()

# %%
# save_to_db(data, 'QDL_FON')

# %%
download_all_tables(tables_filters)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): data.nasdaq.com:443
# DEBUG:urllib3.connectionpool:https://data.nasdaq.com:443 "GET /api/v3/datatables/DY/FDEQU HTTP/1.1" 200 None
# Data saved to dy_fdequ table successfully.
# Total time taken: 4.75 seconds

# %%
query = "SELECT * FROM DY_FDEQU "
# DY/FDEQU
retrieved_data = retrieve_data(query, engine)
retrieved_data.head()
# Out:
#   ticker_symbol exchange_code equity_type  \
# 0        000001          XSHE           A
# 1        000002          XSHE           A
# 2        000009          XSHE           A
# 3        000651          XSHE           A
# 4        000776          XSHE           A
#
#                              security_name exchange_country_code  \
# 0                   Ping An Bank Co., Ltd.                   CHN
# 1                    China Vanke Co., Ltd.                   CHN
# 2               China Baoan Group Co.,Ltd.                   CHN
# 3  Gree Electric Appliances,Inc. of Zhuhai                   CHN
# 4                  GF Securities Co., Ltd.                   CHN
#
#   transaction_currency_code listing_status listing_date delisting_date  \
# 0                       CNY              L   1991-04-03           None
# 1                       CNY              L   1991-01-29           None
# 2                       CNY              L   1991-06-25           None
# 3                       CNY              L   1996-11-18           None
# 4                       CNY              L   1997-06-11           None
#
#   last_updated
# 0   2017-03-17
# 1   2019-08-20
# 2   2017-04-28
# 3   2019-08-20
# 4   2020-09-02

# %%
retrieved_data.columns
# Out:
# Index(['ticker_symbol', 'exchange_code', 'equity_type', 'security_name',
#        'exchange_country_code', 'transaction_currency_code', 'listing_status',
#        'listing_date', 'delisting_date', 'last_updated'],
#       dtype='object')

# %%
query = "SELECT * FROM ZILLOW_DATA"
retrieved_data = retrieve_data(query, engine)
retrieved_data.head()
# Out:
#   indicator_id region_id       date          value
# 0         ZSFH     99999 2024-04-30  471998.338021
# 1         ZSFH     99999 2024-03-31  470671.863494
# 2         ZSFH     99999 2024-02-29  471144.364833
# 3         ZSFH     99999 2024-01-31  474834.034632
# 4         ZSFH     99999 2023-12-31  478670.136789

# %%
current_dir = os.path.abspath('')
pkl_file_path = os.path.join(current_dir, '..', 'data', 'info_dict.pkl')


with open(pkl_file_path, 'rb') as f:
    data = pickle.load(f)

print(data)
# Out:
# {'NDAQ/RTAT10': {'url': ['https://data.nasdaq.com/databases/RTAT'], 'vendor_code': 'NDAQ', 'datatable_code': 'RTAT10', 'name': 'Retail Trading Activity Tracker - Daily Top 10 (Free)', 'description': None, 'columns': [{'name': 'date', 'type': 'Date'}, {'name': 'ticker', 'type': 'text'}, {'name': 'activity', 'type': 'double'}, {'name': 'sentiment', 'type': 'Integer'}], 'filters': ['ticker', 'date'], 'primary_key': ['date', 'ticker'], 'premium': False, 'status': {'refreshed_at': datetime.datetime(2024, 6, 15, 3, 12, 50, tzinfo=tzutc()), 'status': 'ON TIME', 'expected_at': '00 10 * * 2-6', 'update_frequency': '10am every Tuesday through Saturday'}, 'data_version': {'code': '1', 'default': True, 'description': None}, 'Type': ['Prices & Volumes']}, 'NDAQ/RTAT': {'url': ['https://data.nasdaq.com/databases/RTAT'], 'vendor_code': 'NDAQ', 'datatable_code': 'RTAT', 'name': 'Retail Trading Activity Tracker - Daily Full Universe (Premium)', 'description': None, 'columns': [{'name': 'date', 'type': 'Date'}, {'name': 'ticker', 'type': 'text'}, {'name': 'activity', 'type': 'double'}, {'name': 'sentiment', 'type': 'Integer'}], 'filters': ['ticker', 'date'], 'primary_key': ['date', 'ticker'], 'premium': True, 'status': {'refreshed_at': datetime.datetime(2024, 6, 15, 3, 9, 7, tzinfo=tzutc()), 'status': 'ON TIME', 'expected_at': '00 10 * * 2-6', 'update_frequency': '10am every Tuesday through Saturday'}, 'data_version': {'code': '1', 'default': True, 'description': None}, 'Type': ['Prices & Volumes']}, 'EVEST/ALL': {'url': ['https://data.nasdaq.com/databases/EVMLW'], 'vendor_code': 'EVEST', 'datatable_code': 'ALL', 'name': 'Asset Allocation', 'description': None, 'columns': [{'name': 'firm_asset_allocation_id', 'type': 'Integer'}, {'name': 'investor_firm_guid', 'type': 'text'}, {'name': 'parent_firm_asset_allocation_id', 'type': 'Integer'}, {'name': 'sequence', 'type': 'Integer'}, {'name': 'allocation_as_of_date', 'type': 'Date'}, {'name': 'asset_class_universe', 'type': 'text'}, {'name': 'current_allocation', 'type': 'double'}, {'name': 'interim_allocation', 'type': 'double'}, {'name': 'target_allocation', 'type': 'double'}, {'name': 'dataset_id', 'type': 'Integer'}, {'name': 'dataset', 'type': 'text'}], 'filters': ['wide_angle_dataset', 'firm_asset_allocation_id', 'is_trial', 'is_sample', 'investor_firm_guid', 'dataset_id', 'asset_class_universe', 'allocation_as_of_date'], 'primary_key': ['firm_asset_allocation_id'], 'premium': True, 'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 2, 51, tzinfo=tzutc()), 'status': 'ON TIME', 'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5', 'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'}, 'data_version': {'code': '5', 'default': True, 'description': None}, 'Type': ['Others']}, 'EVEST/CONS': {'url': ['https://data.nasdaq.com/databases/EVML'], 'vendor_code': 'EVEST', 'datatable_code': 'CONS', 'name': 'Consultant Clients', 'description': None, 'columns': [{'name': 'investor_firm_guid', 'type': 'text'}, {'name': 'consultant_firm_guid', 'type': 'text'}, {'name': 'services_rendered', 'type': 'text'}, {'name': 'fees', 'type': 'double'}], 'filters': ['is_trial', 'is_sample', 'investor_firm_guid', 'consultant_firm_guid'], 'primary_key': [], 'premium': True, 'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 5, 47, tzinfo=tzutc()), 'status': 'ON TIME', 'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5', 'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'}, 'data_version': {'code': '3', 'default': True, 'description': None}, 'Type': ['Others']}, 'EVEST/FIRM': {'url': ['https://data.nasdaq.com/databases/EVMLW'], 'vendor_code': 'EVEST', 'datatable_code': 'FIRM', 'name': 'Firm Information', 'description': None, 'columns': [{'name': 'firm_guid', 'type': 'text'}, {'name': 'firm_name', 'type': 'tex ...

# %%
data
# Out:
# {'NDAQ/RTAT10': {'url': ['https://data.nasdaq.com/databases/RTAT'],
#   'vendor_code': 'NDAQ',
#   'datatable_code': 'RTAT10',
#   'name': 'Retail Trading Activity Tracker - Daily Top 10 (Free)',
#   'description': None,
#   'columns': [{'name': 'date', 'type': 'Date'},
#    {'name': 'ticker', 'type': 'text'},
#    {'name': 'activity', 'type': 'double'},
#    {'name': 'sentiment', 'type': 'Integer'}],
#   'filters': ['ticker', 'date'],
#   'primary_key': ['date', 'ticker'],
#   'premium': False,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 15, 3, 12, 50, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '00 10 * * 2-6',
#    'update_frequency': '10am every Tuesday through Saturday'},
#   'data_version': {'code': '1', 'default': True, 'description': None},
#   'Type': ['Prices & Volumes']},
#  'NDAQ/RTAT': {'url': ['https://data.nasdaq.com/databases/RTAT'],
#   'vendor_code': 'NDAQ',
#   'datatable_code': 'RTAT',
#   'name': 'Retail Trading Activity Tracker - Daily Full Universe (Premium)',
#   'description': None,
#   'columns': [{'name': 'date', 'type': 'Date'},
#    {'name': 'ticker', 'type': 'text'},
#    {'name': 'activity', 'type': 'double'},
#    {'name': 'sentiment', 'type': 'Integer'}],
#   'filters': ['ticker', 'date'],
#   'primary_key': ['date', 'ticker'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 15, 3, 9, 7, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '00 10 * * 2-6',
#    'update_frequency': '10am every Tuesday through Saturday'},
#   'data_version': {'code': '1', 'default': True, 'description': None},
#   'Type': ['Prices & Volumes']},
#  'EVEST/ALL': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'ALL',
#   'name': 'Asset Allocation',
#   'description': None,
#   'columns': [{'name': 'firm_asset_allocation_id', 'type': 'Integer'},
#    {'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'parent_firm_asset_allocation_id', 'type': 'Integer'},
#    {'name': 'sequence', 'type': 'Integer'},
#    {'name': 'allocation_as_of_date', 'type': 'Date'},
#    {'name': 'asset_class_universe', 'type': 'text'},
#    {'name': 'current_allocation', 'type': 'double'},
#    {'name': 'interim_allocation', 'type': 'double'},
#    {'name': 'target_allocation', 'type': 'double'},
#    {'name': 'dataset_id', 'type': 'Integer'},
#    {'name': 'dataset', 'type': 'text'}],
#   'filters': ['wide_angle_dataset',
#    'firm_asset_allocation_id',
#    'is_trial',
#    'is_sample',
#    'investor_firm_guid',
#    'dataset_id',
#    'asset_class_universe',
#    'allocation_as_of_date'],
#   'primary_key': ['firm_asset_allocation_id'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 2, 51, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '5', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/CONS': {'url': ['https://data.nasdaq.com/databases/EVML'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'CONS',
#   'name': 'Consultant Clients',
#   'description': None,
#   'columns': [{'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'consultant_firm_guid', 'type': 'text'},
#    {'name': 'services_rendered', 'type': 'text'},
#    {'name': 'fees', 'type': 'double'}],
#   'filters': ['is_trial',
#    'is_sample',
#    'investor_firm_guid',
#    'consultant_firm_guid'],
#   'primary_key': [],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 5, 47, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '3', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/FIRM': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'FIRM',
#   'name': 'Firm Information',
#   'description': None,
#   'columns': [{'name': 'firm_guid', 'type': 'text'},
#    {'name': 'firm_name', 'type': 'text'},
#    {'name': 'firm_display_name', 'type': 'text'},
#    {'name': 'firm_short_name', 'type': 'text'},
#    {'name': 'evestment_manager_firm_guid', 'type': 'text'},
#    {'name': 'firm_type_code', 'type': 'text'},
#    {'name': 'firm_sub_type_code', 'type': 'text'},
#    {'name': 'naic_code', 'type': 'Integer'},
#    {'name': 'naic_type', 'type': 'text'},
#    {'name': 'firm_website', 'type': 'text'},
#    {'name': 'firm_profile_url', 'type': 'text'},
#    {'name': 'inserted_on', 'type': 'datetime'},
#    {'name': 'updated_on', 'type': 'datetime'},
#    {'name': 'firm_city', 'type': 'text'},
#    {'name': 'firm_state', 'type': 'text'},
#    {'name': 'firm_zip_code', 'type': 'text'},
#    {'name': 'firm_country', 'type': 'text'},
#    {'name': 'currency_code', 'type': 'text'},
#    {'name': 'total_assets', 'type': 'double'},
#    {'name': 'defined_benefit_assets', 'type': 'double'},
#    {'name': 'defined_contribution_assets', 'type': 'double'},
#    {'name': 'total_endowment_and_foundations_assets', 'type': 'double'},
#    {'name': 'total_insurance_long_term_assets', 'type': 'double'},
#    {'name': 'total_insurance_affiliated_assets', 'type': 'double'},
#    {'name': 'total_insurance_unaffiliated_assets', 'type': 'double'},
#    {'name': 'total_fiduciary_allocator_assets_unaffiliated', 'type': 'double'},
#    {'name': 'assets_source_reviewed_date', 'type': 'datetime'},
#    {'name': 'public_client_count', 'type': 'Integer'},
#    {'name': 'corporate_client_count', 'type': 'Integer'},
#    {'name': 'non_profit_client_count', 'type': 'Integer'},
#    {'name': 'taft_hartley_union_client_count', 'type': 'Integer'},
#    {'name': 'other_client_count', 'type': 'Integer'},
#    {'name': 'total_client_count', 'type': 'Integer'},
#    {'name': 'client_count_source_reviewed_date', 'type': 'datetime'},
#    {'name': 'primary_investor_type_dataset_id', 'type': 'Integer'},
#    {'name': 'primary_investor_type_dataset', 'type': 'text'},
#    {'name': 'secondary_investor_type_dataset_id', 'type': 'Integer'},
#    {'name': 'secondary_investor_type_dataset', 'type': 'text'}],
#   'filters': ['wide_angle_dataset',
#    'secondary_investor_type_dataset_id',
#    'primary_investor_type_dataset_id',
#    'firm_guid',
#    'is_trial',
#    'is_sample',
#    'firm_type_code',
#    'firm_sub_type_code',
#    'firm_country',
#    'evestment_manager_firm_guid'],
#   'primary_key': ['firm_guid'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 13, 46, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '7', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/REL': {'url': ['https://data.nasdaq.com/databases/EVML'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'REL',
#   'name': 'Firm Relation',
#   'description': None,
#   'columns': [{'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'consultant_firm_guid', 'type': 'text'},
#    {'name': 'role', 'type': 'text'}],
#   'filters': ['is_trial',
#    'is_sample',
#    'investor_firm_guid',
#    'consultant_firm_guid'],
#   'primary_key': [],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 11, 32, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '2', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/RELK': {'url': ['https://data.nasdaq.com/databases/EVML'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'RELK',
#   'name': 'Firm Relation Key Contact',
#   'description': None,
#   'columns': [{'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'consultant_firm_guid', 'type': 'text'},
#    {'name': 'key_contact_name', 'type': 'text'}],
#   'filters': ['is_trial',
#    'is_sample',
#    'investor_firm_guid',
#    'consultant_firm_guid'],
#   'primary_key': [],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 10, 29, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '2', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/ROS': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'ROS',
#   'name': 'Manager Roster',
#   'description': None,
#   'columns': [{'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'filing_guid', 'type': 'text'},
#    {'name': 'sponsor_evestment_manager_firm_guid', 'type': 'text'},
#    {'name': 'sponsor_manager_firm_name', 'type': 'text'},
#    {'name': 'manager', 'type': 'text'},
#    {'name': 'evestment_manager_firm_guid', 'type': 'text'},
#    {'name': 'manager_since_date', 'type': 'Date'},
#    {'name': 'consultant_firm_guid', 'type': 'text'},
#    {'name': 'asset_class', 'type': 'text'},
#    {'name': 'asset_allocation_bucket', 'type': 'text'},
#    {'name': 'sub_asset_class', 'type': 'text'},
#    {'name': 'region', 'type': 'text'},
#    {'name': 'sub_region', 'type': 'text'},
#    {'name': 'stage', 'type': 'text'},
#    {'name': 'sector', 'type': 'text'},
#    {'name': 'strategy', 'type': 'text'},
#    {'name': 'product_name', 'type': 'text'},
#    {'name': 'evestment_product_guid', 'type': 'text'},
#    {'name': 'vehicle_name', 'type': 'text'},
#    {'name': 'benchmark', 'type': 'text'},
#    {'name': 'universe', 'type': 'text'},
#    {'name': 'evestment_universe_guid', 'type': 'text'},
#    {'name': 'currency_code', 'type': 'text'},
#    {'name': 'estimated_market_value', 'type': 'double'},
#    {'name': 'percent_of_portfolio', 'type': 'double'},
#    {'name': 'commitment', 'type': 'double'},
#    {'name': 'unfunded_commitment', 'type': 'double'},
#    {'name': 'capital_called', 'type': 'double'},
#    {'name': 'capital_returned', 'type': 'double'},
#    {'name': 'investor_reported_return_mrq', 'type': 'double'},
#    {'name': 'investor_reported_return_ytd', 'type': 'double'},
#    {'name': 'investor_reported_return_1yr', 'type': 'double'},
#    {'name': 'investor_reported_return_3yr', 'type': 'double'},
#    {'name': 'investor_reported_return_5yr', 'type': 'double'},
#    {'name': 'investor_reported_performance_as_of_date', 'type': 'Date'},
#    {'name': 'manager_reported_returns_mrq', 'type': 'double'},
#    {'name': 'manager_reported_returns_mrq_quartile', 'type': 'double'},
#    {'name': 'manager_reported_returns_mrq_benchmark', 'type': 'double'},
#    {'name': 'manager_reported_excess_returns_mrq', 'type': 'double'},
#    {'name': 'manager_reported_returns_1yr', 'type': 'double'},
#    {'name': 'manager_reported_returns_1yr_quartile', 'type': 'double'},
#    {'name': 'manager_reported_returns_1yr_benchmark', 'type': 'double'},
#    {'name': 'manager_reported_excess_returns_1yr', 'type': 'double'},
#    {'name': 'manager_reported_returns_3yr', 'type': 'double'},
#    {'name': 'manager_reported_returns_3yr_quartile', 'type': 'double'},
#    {'name': 'manager_reported_returns_3yr_benchmark', 'type': 'double'},
#    {'name': 'manager_reported_excess_returns_3yr', 'type': 'double'},
#    {'name': 'manager_reported_returns_5yr', 'type': 'double'},
#    {'name': 'manager_reported_returns_5yr_quartile', 'type': 'double'},
#    {'name': 'manager_reported_returns_5yr_benchmark', 'type': 'double'},
#    {'name': 'manager_reported_excess_returns_5yr', 'type': 'double'},
#    {'name': 'manager_reported_performance_as_of_date', 'type': 'Date'},
#    {'name': 'irr', 'type': 'double'},
#    {'name': 'vintage_year', 'type': 'Integer'},
#    {'name': 'multiple', 'type': 'double'},
#    {'name': 'blended_fee', 'type': 'double'},
#    {'name': 'fee_schedule', 'type': 'text'},
#    {'name': 'fee_as_of_date', 'type': 'Date'},
#    {'name': 'naic_code', 'type': 'Integer'},
#    {'name': 'naic_category', 'type': 'text'},
#    {'name': 'date_acquired', 'type': 'Date'},
#    {'name': 'unrealized_valuation_change', 'type': 'double'},
#    {'name': 'commitment_for_additional_investment', 'type': 'double'},
#    {'name': 'percent_ownership', 'type': 'double'},
#    {'name': 'actual_cost', 'type': 'double'},
#    {'name': 'book_value', 'type': 'double'},
#    {'name': 'current_depreciation_amortization', 'type': 'double'},
#    {'name': 'foreign_exchange_change_in_book_value', 'type': 'double'},
#    {'name': 'insurance_investor_city', 'type': 'text'},
#    {'name': 'insurance_investor_state', 'type': 'text'},
#    {'name': 'primary_activities', 'type': 'text'},
#    {'name': 'fiduciary_allocator_fund_guid', 'type': 'text'},
#    {'name': 'sub_advisor_fee_source', 'type': 'text'},
#    {'name': 'manager_assets_percent_of_fund', 'type': 'double'},
#    {'name': 'is_affiliated', 'type': 'text'},
#    {'name': 'period', 'type': 'Integer'},
#    {'name': 'source', 'type': 'text'},
#    {'name': 'source_url', 'type': 'text'},
#    {'name': 'composite_id', 'type': 'text'},
#    {'name': 'is_latest_period', 'type': 'text'},
#    {'name': 'dataset_id', 'type': 'Integer'},
#    {'name': 'dataset', 'type': 'text'}],
#   'filters': ['wide_angle_dataset',
#    'is_trial',
#    'is_sample',
#    'is_latest_period',
#    'investor_firm_guid',
#    'evestment_universe_guid',
#    'evestment_product_guid',
#    'evestment_manager_firm_guid',
#    'dataset_id',
#    'asset_class'],
#   'primary_key': [],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 28, 52, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '00 10 * * 1-5',
#    'update_frequency': '10am every Monday through Friday'},
#   'data_version': {'code': '10', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/MAND': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'MAND',
#   'name': 'Mandates',
#   'description': None,
#   'columns': [{'name': 'mandate_guid', 'type': 'text'},
#    {'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'consultant_firm_guid', 'type': 'text'},
#    {'name': 'universe', 'type': 'text'},
#    {'name': 'evestment_universe_guid', 'type': 'text'},
#    {'name': 'allocation_change_from', 'type': 'double'},
#    {'name': 'allocation_change_to', 'type': 'double'},
#    {'name': 'asset_class', 'type': 'text'},
#    {'name': 'commitment', 'type': 'double'},
#    {'name': 'currency_code', 'type': 'text'},
#    {'name': 'inserted_on', 'type': 'datetime'},
#    {'name': 'is_passive', 'type': 'text'},
#    {'name': 'mandate_category', 'type': 'text'},
#    {'name': 'mandate_plan_type', 'type': 'text'},
#    {'name': 'mandate_plan_type_id', 'type': 'Integer'},
#    {'name': 'mandate_profile_url', 'type': 'text'},
#    {'name': 'mandate_type', 'type': 'text'},
#    {'name': 'region', 'type': 'text'},
#    {'name': 'rfp_issue_date', 'type': 'Date'},
#    {'name': 'rfp_response_deadline_date', 'type': 'Date'},
#    {'name': 'rfp_url', 'type': 'text'},
#    {'name': 'updated_on', 'type': 'datetime'},
#    {'name': 'has_rfp', 'type': 'text'},
#    {'name': 'is_mwdbe', 'type': 'text'},
#    {'name': 'is_emerging_manager', 'type': 'text'},
#    {'name': 'is_esg', 'type': 'text'},
#    {'name': 'consultant_contact', 'type': 'text'},
#    {'name': 'reason_for_hire', 'type': 'text'},
#    {'name': 'sub_asset_class', 'type': 'text'},
#    {'name': 'sector', 'type': 'text'},
#    {'name': 'stage', 'type': 'text'},
#    {'name': 'mandate_source_type', 'type': 'text'},
#    {'name': 'dataset_id', 'type': 'Integer'},
#    {'name': 'dataset', 'type': 'text'}],
#   'filters': ['wide_angle_dataset',
#    'region',
#    'mandate_guid',
#    'is_trial',
#    'is_sample',
#    'investor_firm_guid',
#    'evestment_universe_guid',
#    'dataset_id',
#    'consultant_firm_guid',
#    'asset_class'],
#   'primary_key': ['mandate_guid'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 5, 53, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '7', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/MANDH': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'MANDH',
#   'name': 'Mandate History',
#   'description': None,
#   'columns': [{'name': 'inserted_on', 'type': 'datetime'},
#    {'name': 'mandate_action', 'type': 'text'},
#    {'name': 'mandate_guid', 'type': 'text'},
#    {'name': 'mandate_history_id', 'type': 'Integer'},
#    {'name': 'mandate_stage', 'type': 'text'},
#    {'name': 'notes', 'type': 'text'},
#    {'name': 'post_date', 'type': 'Date'},
#    {'name': 'document_url', 'type': 'text'},
#    {'name': 'updated_on', 'type': 'datetime'},
#    {'name': 'dataset_id', 'type': 'Integer'},
#    {'name': 'dataset', 'type': 'text'}],
#   'filters': ['wide_angle_dataset',
#    'updated_on',
#    'mandate_history_id',
#    'mandate_stage',
#    'mandate_guid',
#    'mandate_action',
#    'is_trial',
#    'is_sample',
#    'dataset_id'],
#   'primary_key': ['mandate_history_id'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 13, 41, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '3', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/MANDP': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'MANDP',
#   'name': 'Mandate Participants',
#   'description': None,
#   'columns': [{'name': 'mandate_guid', 'type': 'text'},
#    {'name': 'mandate_participant_id', 'type': 'Integer'},
#    {'name': 'participant_firm_name', 'type': 'text'},
#    {'name': 'evestment_manager_firm_guid', 'type': 'text'},
#    {'name': 'product_name', 'type': 'text'},
#    {'name': 'evestment_product_guid', 'type': 'text'},
#    {'name': 'commitment', 'type': 'double'},
#    {'name': 'currency_code', 'type': 'text'},
#    {'name': 'inserted_on', 'type': 'datetime'},
#    {'name': 'is_being_replaced', 'type': 'text'},
#    {'name': 'is_finalist', 'type': 'text'},
#    {'name': 'is_winner', 'type': 'text'},
#    {'name': 'presentation_url', 'type': 'text'},
#    {'name': 'updated_on', 'type': 'datetime'},
#    {'name': 'sub_asset_class', 'type': 'text'},
#    {'name': 'sector', 'type': 'text'},
#    {'name': 'stage', 'type': 'text'},
#    {'name': 'dataset_id', 'type': 'Integer'},
#    {'name': 'dataset', 'type': 'text'}],
#   'filters': ['wide_angle_dataset',
#    'mandate_participant_id',
#    'mandate_guid',
#    'is_trial',
#    'is_sample',
#    'is_finalist',
#    'is_being_replaced',
#    'inserted_on',
#    'evestment_manager_firm_guid',
#    'dataset_id'],
#   'primary_key': ['mandate_participant_id'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 10, 45, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '4', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/RAT': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'RAT',
#   'name': 'Product Ratings',
#   'description': None,
#   'columns': [{'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'consultant_firm_guid', 'type': 'text'},
#    {'name': 'manager', 'type': 'text'},
#    {'name': 'evestment_manager_firm_guid', 'type': 'text'},
#    {'name': 'product_name', 'type': 'text'},
#    {'name': 'evestment_product_guid', 'type': 'text'},
#    {'name': 'universe', 'type': 'text'},
#    {'name': 'evestment_universe_guid', 'type': 'text'},
#    {'name': 'region', 'type': 'text'},
#    {'name': 'asset_class', 'type': 'text'},
#    {'name': 'rating_as_of_date', 'type': 'Date'},
#    {'name': 'recommendation_and_rating', 'type': 'text'},
#    {'name': 'sub_recommendation_and_rating', 'type': 'text'},
#    {'name': 'mandate_guid', 'type': 'text'},
#    {'name': 'sub_asset_class', 'type': 'text'},
#    {'name': 'sector', 'type': 'text'},
#    {'name': 'stage', 'type': 'text'},
#    {'name': 'dataset_id', 'type': 'Integer'},
#    {'name': 'dataset', 'type': 'text'}],
#   'filters': ['wide_angle_dataset',
#    'recommendation_and_rating',
#    'is_trial',
#    'is_sample',
#    'investor_firm_guid',
#    'evestment_universe_guid',
#    'evestment_product_guid',
#    'evestment_manager_firm_guid',
#    'dataset_id',
#    'consultant_firm_guid',
#    'asset_class'],
#   'primary_key': [],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 16, 54, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '5', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/PLAN': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'PLAN',
#   'name': 'Plans',
#   'description': None,
#   'columns': [{'name': 'plan_id', 'type': 'text'},
#    {'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'ein', 'type': 'Integer'},
#    {'name': 'plan_filing_guid', 'type': 'text'},
#    {'name': 'filing_period', 'type': 'Date'},
#    {'name': 'plan_guid', 'type': 'text'},
#    {'name': 'plan_name', 'type': 'text'},
#    {'name': 'plan_number', 'type': 'Integer'},
#    {'name': 'total_assets', 'type': 'double'},
#    {'name': 'plan_type', 'type': 'text'},
#    {'name': 'funded_status', 'type': 'double'},
#    {'name': 'plan_administrator', 'type': 'text'},
#    {'name': 'is_defined_benefit', 'type': 'Integer'},
#    {'name': 'total_active_participants_beginning_of_year_count',
#     'type': 'Integer'},
#    {'name': 'total_active_participants_end_of_year_count', 'type': 'Integer'},
#    {'name': 'retired_or_separated_receiving_benefits_count',
#     'type': 'Integer'},
#    {'name': 'other_retired_or_separated_future_entitled_count',
#     'type': 'Integer'},
#    {'name': 'participant_subtotal', 'type': 'Integer'},
#    {'name': 'deceased_participants_beneficiaries_benefits', 'type': 'Integer'},
#    {'name': 'participant_total', 'type': 'Integer'},
#    {'name': 'participant_account_balance_count', 'type': 'Integer'},
#    {'name': 'terminated_participants_partially_vested_count',
#     'type': 'Integer'},
#    {'name': 'dfe_type', 'type': 'text'},
#    {'name': 'is_latest_period', 'type': 'text'},
#    {'name': 'dataset_id', 'type': 'Integer'},
#    {'name': 'dataset', 'type': 'text'}],
#   'filters': ['wide_angle_dataset',
#    'total_assets',
#    'plan_id',
#    'plan_guid',
#    'plan_filing_guid',
#    'is_trial',
#    'is_sample',
#    'is_latest_period',
#    'investor_firm_guid',
#    'filing_period',
#    'ein',
#    'dataset_id'],
#   'primary_key': ['plan_filing_guid'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 22, 26, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '5', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/DALL': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'DALL',
#   'name': 'DOL Asset Allocations',
#   'description': None,
#   'columns': [{'name': 'plan_filing_guid', 'type': 'text'},
#    {'name': 'percentage_assets_held_as_stock', 'type': 'double'},
#    {'name': 'percentage_assets_held_as_investment_grade_debt',
#     'type': 'double'},
#    {'name': 'percentage_assets_held_as_high_yield_debt', 'type': 'double'},
#    {'name': 'percentage_assets_held_as_real_estate', 'type': 'double'},
#    {'name': 'percentage_assets_held_as_other', 'type': 'double'},
#    {'name': 'average_duration_combined_debt', 'type': 'text'},
#    {'name': 'employer_contributions', 'type': 'double'},
#    {'name': 'participant_contributions', 'type': 'double'},
#    {'name': 'receivables_other', 'type': 'double'},
#    {'name': 'interest_bearing_cash', 'type': 'double'},
#    {'name': 'us_government_securities', 'type': 'double'},
#    {'name': 'corporate_debt_instruments_preferred', 'type': 'double'},
#    {'name': 'corporate_debt_instruments_other', 'type': 'double'},
#    {'name': 'corporate_stocks_preferred', 'type': 'double'},
#    {'name': 'corporate_stocks_other', 'type': 'double'},
#    {'name': 'partnership_joint_venture_interests', 'type': 'double'},
#    {'name': 'real_estate', 'type': 'double'},
#    {'name': 'non_participant_loans', 'type': 'double'},
#    {'name': 'participant_loans', 'type': 'double'},
#    {'name': 'common_collective_trusts_interest_value', 'type': 'double'},
#    {'name': 'pooled_separate_accounts_interest_value', 'type': 'double'},
#    {'name': 'master_trust_investment_accounts_interest_value',
#     'type': 'double'},
#    {'name': 'one_zero_three_one_two_investment_entities_interest_values',
#     'type': 'double'},
#    {'name': 'registered_investment_companies_interest_values',
#     'type': 'double'},
#    {'name': 'insurance_company_held_general_account_value', 'type': 'double'},
#    {'name': 'general_investments_other', 'type': 'double'},
#    {'name': 'employer_securities', 'type': 'double'},
#    {'name': 'employer_real_property', 'type': 'double'},
#    {'name': 'buildings_and_other_property_used_in_plan_operation',
#     'type': 'double'},
#    {'name': 'total_assets', 'type': 'double'},
#    {'name': 'benefit_claims_payable', 'type': 'double'},
#    {'name': 'operating_payables', 'type': 'double'},
#    {'name': 'acquisition_indebtedness', 'type': 'double'},
#    {'name': 'other_liabilities', 'type': 'double'},
#    {'name': 'total_liabilities', 'type': 'double'},
#    {'name': 'net_assets', 'type': 'double'},
#    {'name': 'calculated_returns', 'type': 'double'}],
#   'filters': ['plan_filing_guid', 'is_sample', 'is_trial'],
#   'primary_key': [],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 11, 1, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '00 10 * * 1-5',
#    'update_frequency': '10am every Monday through Friday'},
#   'data_version': {'code': '3', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/SER': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'SER',
#   'name': 'Service Providers',
#   'description': None,
#   'columns': [{'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'filing_guid', 'type': 'text'},
#    {'name': 'service_provider_firm_guid', 'type': 'text'},
#    {'name': 'service_provider_name', 'type': 'text'},
#    {'name': 'roles', 'type': 'text'},
#    {'name': 'fees', 'type': 'double'},
#    {'name': 'is_former_service_provider', 'type': 'text'},
#    {'name': 'service_provider_key_professionals', 'type': 'text'},
#    {'name': 'service_provider_key_professionals_source_url', 'type': 'text'},
#    {'name': 'source_url', 'type': 'text'},
#    {'name': 'dataset', 'type': 'text'},
#    {'name': 'dataset_id', 'type': 'Integer'}],
#   'filters': ['wide_angle_dataset',
#    'service_provider_firm_guid',
#    'is_trial',
#    'is_sample',
#    'is_former_service_provider',
#    'investor_firm_guid',
#    'filing_guid',
#    'dataset_id'],
#   'primary_key': [],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 22, 19, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '4', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/DROS': {'url': ['https://data.nasdaq.com/databases/EVML'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'DROS',
#   'name': 'DOL Manager Roster',
#   'description': None,
#   'columns': [{'name': 'plan_filing_guid', 'type': 'text'},
#    {'name': 'firm', 'type': 'text'},
#    {'name': 'evestment_manager_firm_guid', 'type': 'text'},
#    {'name': 'product_name', 'type': 'text'},
#    {'name': 'evestment_product_guid', 'type': 'text'},
#    {'name': 'universe', 'type': 'text'},
#    {'name': 'evestment_universe_guid', 'type': 'text'},
#    {'name': 'estimated_value', 'type': 'double'}],
#   'filters': ['plan_filing_guid',
#    'is_sample',
#    'is_trial',
#    'evestment_universe_guid',
#    'evestment_manager_firm_guid'],
#   'primary_key': [],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 20, 6, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '00 10 * * 1-5',
#    'update_frequency': '10am every Monday through Friday'},
#   'data_version': {'code': '2', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/CNTS': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'CNTS',
#   'name': 'Firm Contacts',
#   'description': None,
#   'columns': [{'name': 'firm_guid', 'type': 'text'},
#    {'name': 'contact_type', 'type': 'text'},
#    {'name': 'prefix', 'type': 'text'},
#    {'name': 'first_name', 'type': 'text'},
#    {'name': 'last_name', 'type': 'text'},
#    {'name': 'suffix', 'type': 'text'},
#    {'name': 'financial_designation', 'type': 'text'},
#    {'name': 'description', 'type': 'text'},
#    {'name': 'job_title', 'type': 'text'},
#    {'name': 'board_title', 'type': 'text'},
#    {'name': 'degree', 'type': 'text'},
#    {'name': 'email', 'type': 'text'},
#    {'name': 'phone', 'type': 'text'},
#    {'name': 'linkedin_url', 'type': 'text'},
#    {'name': 'is_investment_committee_member', 'type': 'text'},
#    {'name': 'specialty', 'type': 'text'},
#    {'name': 'street_address', 'type': 'text'},
#    {'name': 'city', 'type': 'text'},
#    {'name': 'state', 'type': 'text'},
#    {'name': 'zip_code', 'type': 'text'},
#    {'name': 'country', 'type': 'text'},
#    {'name': 'source_reviewed_date', 'type': 'Date'},
#    {'name': 'is_former_employee', 'type': 'text'},
#    {'name': 'dataset', 'type': 'text'},
#    {'name': 'dataset_id', 'type': 'Integer'}],
#   'filters': ['wide_angle_dataset',
#    'is_trial',
#    'is_sample',
#    'firm_guid',
#    'dataset_id',
#    'contact_type',
#    'city'],
#   'primary_key': [],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 6, 58, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '5', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/DOCUMENTS': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'DOCUMENTS',
#   'name': 'Documents',
#   'description': None,
#   'columns': [{'name': 'doc_id', 'type': 'Integer'},
#    {'name': 'name', 'type': 'text'},
#    {'name': 'document_date', 'type': 'datetime'},
#    {'name': 'document_url', 'type': 'text'},
#    {'name': 'page_count', 'type': 'Integer'},
#    {'name': 'date_added', 'type': 'datetime'},
#    {'name': 'document_type', 'type': 'text'},
#    {'name': 'author_type', 'type': 'text'},
#    {'name': 'ppiq_investor_id', 'type': 'Integer'},
#    {'name': 'investor', 'type': 'text'},
#    {'name': 'investor_state_or_province', 'type': 'text'},
#    {'name': 'investor_country', 'type': 'text'},
#    {'name': 'manager_guid', 'type': 'text'},
#    {'name': 'manager', 'type': 'text'},
#    {'name': 'ppiq_consultant_id', 'type': 'Integer'},
#    {'name': 'consultant', 'type': 'text'},
#    {'name': 'product_name', 'type': 'text'},
#    {'name': 'notes', 'type': 'text'},
#    {'name': 'geographic_region', 'type': 'text'},
#    {'name': 'strategy', 'type': 'text'},
#    {'name': 'has_fees_disclosed', 'type': 'text'},
#    {'name': 'investor_commitment_in_millions', 'type': 'double'},
#    {'name': 'fee_structure_terms', 'type': 'text'},
#    {'name': 'management_fee', 'type': 'double'},
#    {'name': 'carry_interest_performance', 'type': 'double'},
#    {'name': 'hurdle', 'type': 'text'},
#    {'name': 'additional_fees_offsets', 'type': 'text'},
#    {'name': 'asset_class', 'type': 'text'},
#    {'name': 'is_environmental_social_governance', 'type': 'text'},
#    {'name': 'is_defined_contribution', 'type': 'text'},
#    {'name': 'audio_visual_type', 'type': 'text'},
#    {'name': 'audio_visual_link', 'type': 'text'},
#    {'name': 'audio_visual_location_comment', 'type': 'text'}],
#   'filters': ['doc_id',
#    'manager_guid',
#    'is_trial',
#    'is_sample',
#    'document_type',
#    'author_type'],
#   'primary_key': ['doc_id'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 12, 7, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '1', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/AD': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'AD',
#   'name': 'Acquisitions and Dispositions',
#   'description': None,
#   'columns': [{'name': 'acquisition_disposition_guid', 'type': 'text'},
#    {'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'naic_code', 'type': 'Integer'},
#    {'name': 'file_date', 'type': 'Date'},
#    {'name': 'is_acquisition', 'type': 'text'},
#    {'name': 'mandate_guid', 'type': 'text'},
#    {'name': 'manager_name', 'type': 'text'},
#    {'name': 'manager_guid', 'type': 'text'},
#    {'name': 'product_name', 'type': 'text'},
#    {'name': 'product_guid', 'type': 'text'},
#    {'name': 'universe_guid', 'type': 'text'},
#    {'name': 'universe', 'type': 'text'},
#    {'name': 'naic_strategy', 'type': 'text'},
#    {'name': 'asset_class', 'type': 'text'},
#    {'name': 'date_originally_acquired', 'type': 'Date'},
#    {'name': 'actual_cost', 'type': 'double'},
#    {'name': 'additional_acquisition_after_initial_investment',
#     'type': 'double'},
#    {'name': 'investment_income', 'type': 'double'},
#    {'name': 'commitment_for_additional_investment', 'type': 'double'},
#    {'name': 'percent_ownership', 'type': 'double'},
#    {'name': 'disposition_date', 'type': 'Date'},
#    {'name': 'consideration', 'type': 'double'},
#    {'name': 'unrealized_valuation_increase_decrease', 'type': 'double'},
#    {'name': 'total_gain_or_loss_on_disposal', 'type': 'double'},
#    {'name': 'name_of_purchase_nature_of_disposition', 'type': 'text'},
#    {'name': 'prior_year_book_carrying_value', 'type': 'double'},
#    {'name': 'total_change_in_book_value', 'type': 'double'},
#    {'name': 'dataset', 'type': 'text'},
#    {'name': 'dataset_id', 'type': 'Integer'}],
#   'filters': ['wide_angle_dataset',
#    'universe_guid',
#    'product_guid',
#    'acquisition_disposition_guid',
#    'mandate_guid',
#    'manager_guid',
#    'is_trial',
#    'is_sample',
#    'investor_firm_guid',
#    'file_date',
#    'disposition_date',
#    'date_originally_acquired',
#    'commitment_for_additional_investment',
#    'asset_class'],
#   'primary_key': ['acquisition_disposition_guid'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 25, 11, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '1', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/RET': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'RET',
#   'name': 'IRS Returns',
#   'description': None,
#   'columns': [{'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'return_filing_guid', 'type': 'text'},
#    {'name': 'ein', 'type': 'Integer'},
#    {'name': 'filing_year', 'type': 'Integer'},
#    {'name': 'assets_cash_non_interest_bearing', 'type': 'double'},
#    {'name': 'assets_savings_and_temporary_cash_investments', 'type': 'double'},
#    {'name': 'assets_pledges_grants_receivables', 'type': 'double'},
#    {'name': 'assets_accounts_receivable', 'type': 'double'},
#    {'name': 'assets_loans_other_receivables', 'type': 'double'},
#    {'name': 'assets_loans_other_receivables_disqualified_persons',
#     'type': 'double'},
#    {'name': 'asset_notes_receivables', 'type': 'double'},
#    {'name': 'assets_inventories_for_sale_or_use', 'type': 'double'},
#    {'name': 'assets_prepaid_expenses_and_deferred_charges', 'type': 'double'},
#    {'name': 'assets_land_buildings_equipment_other_basis', 'type': 'double'},
#    {'name': 'assets_land_bldgs_eqpt_oth_basis_less_accum_depr',
#     'type': 'double'},
#    {'name': 'assets_investments_publicly_traded_securities', 'type': 'double'},
#    {'name': 'assets_investments_other_securities', 'type': 'double'},
#    {'name': 'assets_investments_program_related', 'type': 'double'},
#    {'name': 'assets_intangible_assets', 'type': 'double'},
#    {'name': 'assets_other', 'type': 'double'},
#    {'name': 'assets_total_assets', 'type': 'double'},
#    {'name': 'liabilities_accounts_payable_accrued_expenses', 'type': 'double'},
#    {'name': 'liabilities_grants_payable', 'type': 'double'},
#    {'name': 'liabilities_deferred_revenue', 'type': 'double'},
#    {'name': 'liabilities_tax_exempt_bond_liabilities', 'type': 'double'},
#    {'name': 'liabilities_escrow_or_custodial_account_liability',
#     'type': 'double'},
#    {'name': 'liabilities_loans_and_other_payables', 'type': 'double'},
#    {'name': 'liabilities_secured_mortgages_and_notes_payable',
#     'type': 'double'},
#    {'name': 'liabilities_unsecured_notes_payable', 'type': 'double'},
#    {'name': 'liabilities_other_liabilities', 'type': 'double'},
#    {'name': 'liabilities_total_liabilities', 'type': 'double'},
#    {'name': 'net_assets_without_donor_restrictions', 'type': 'double'},
#    {'name': 'net_assets_with_donor_restrictions', 'type': 'double'},
#    {'name': 'net_assets_paid_in_cap_sur_land_bldgs_eqpt_fund',
#     'type': 'double'},
#    {'name': 'net_assets_re_accum_income_endowment_oth_funds',
#     'type': 'double'},
#    {'name': 'net_assets_total_net_assets_fund_balances', 'type': 'double'},
#    {'name': 'total_liabilities_net_assets_fund_balances', 'type': 'double'},
#    {'name': 'dataset_id', 'type': 'Integer'},
#    {'name': 'dataset', 'type': 'text'}],
#   'filters': ['wide_angle_dataset',
#    'return_filing_guid',
#    'is_trial',
#    'is_sample',
#    'investor_firm_guid',
#    'ein',
#    'dataset_id'],
#   'primary_key': ['return_filing_guid'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 11, 52, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '1', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/RETPF': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'RETPF',
#   'name': 'IRS Returns Private Foundation',
#   'description': None,
#   'columns': [{'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'return_filing_guid', 'type': 'text'},
#    {'name': 'ein', 'type': 'Integer'},
#    {'name': 'filing_year', 'type': 'Integer'},
#    {'name': 'assets_cash_non_interest_bearing', 'type': 'double'},
#    {'name': 'assets_savings_and_temporary_cash_investments', 'type': 'double'},
#    {'name': 'assets_pledges_receivable', 'type': 'double'},
#    {'name': 'assets_accounts_receivable', 'type': 'double'},
#    {'name': 'assets_accounts_receivable_less_allowance', 'type': 'double'},
#    {'name': 'assets_pledges_grants_receivables_less_allowance',
#     'type': 'double'},
#    {'name': 'assets_grants_receivable', 'type': 'double'},
#    {'name': 'assets_receivables_due_from_officers_directors',
#     'type': 'double'},
#    {'name': 'assets_other_notes_and_loans_receivable', 'type': 'double'},
#    {'name': 'assets_other_notes_and_loans_receivable_less_allowance',
#     'type': 'double'},
#    {'name': 'assets_inventories_for_sale_or_use', 'type': 'double'},
#    {'name': 'assets_prepaid_expenses_and_deferred_charges', 'type': 'double'},
#    {'name': 'assets_investments_us_and_state_govt_obligations',
#     'type': 'double'},
#    {'name': 'assets_investments_corporate_stock', 'type': 'double'},
#    {'name': 'assets_investments_corporate_bonds', 'type': 'double'},
#    {'name': 'assets_investments_land_buildings_equipment', 'type': 'double'},
#    {'name': 'assets_investments_land_bldgs_eqpt_less_accum_depr',
#     'type': 'double'},
#    {'name': 'assets_investments_mortgage_loans', 'type': 'double'},
#    {'name': 'assets_investments_other', 'type': 'double'},
#    {'name': 'assets_other', 'type': 'double'},
#    {'name': 'assets_total_assets', 'type': 'double'},
#    {'name': 'liabilities_accounts_payable_accrued_expenses', 'type': 'double'},
#    {'name': 'liabilities_grants_payable', 'type': 'double'},
#    {'name': 'liabilities_deferred_revenue', 'type': 'double'},
#    {'name': 'liabilities_loans_from_officers_directors', 'type': 'double'},
#    {'name': 'liabilities_mortgages_and_other_notes_payable', 'type': 'double'},
#    {'name': 'liabilities_other_liabilities', 'type': 'double'},
#    {'name': 'liabilities_total_liabilities', 'type': 'double'},
#    {'name': 'net_assets_without_donor_restrictions', 'type': 'double'},
#    {'name': 'net_assets_with_donor_restrictions', 'type': 'double'},
#    {'name': 'net_assets_cap_stock_trust_prin_current_funds', 'type': 'double'},
#    {'name': 'net_assets_paid_in_cap_sur_land_bldgs_eqpt_fund',
#     'type': 'double'},
#    {'name': 'net_assets_re_accum_income_endowment_oth_funds',
#     'type': 'double'},
#    {'name': 'net_assets_total_net_assets_fund_balances', 'type': 'double'},
#    {'name': 'total_liabilities_net_assets_fund_balances', 'type': 'double'},
#    {'name': 'dataset_id', 'type': 'Integer'},
#    {'name': 'dataset', 'type': 'text'}],
#   'filters': ['wide_angle_dataset',
#    'return_filing_guid',
#    'is_trial',
#    'is_sample',
#    'investor_firm_guid',
#    'filing_year',
#    'ein',
#    'dataset_id'],
#   'primary_key': ['return_filing_guid'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 22, 27, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '1', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/RETOS': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'RETOS',
#   'name': 'IRS Returns Other Securities',
#   'description': None,
#   'columns': [{'name': 'return_filing_guid', 'type': 'text'},
#    {'name': 'security_description', 'type': 'text'},
#    {'name': 'book_value_amount', 'type': 'double'},
#    {'name': 'dataset_id', 'type': 'Integer'},
#    {'name': 'dataset', 'type': 'text'}],
#   'filters': ['wide_angle_dataset',
#    'return_filing_guid',
#    'is_trial',
#    'is_sample',
#    'dataset_id'],
#   'primary_key': [],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 17, 52, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '1', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/FAF': {'url': ['https://data.nasdaq.com/databases/EVMLW'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'FAF',
#   'name': 'Fiduciary Allocator Funds',
#   'description': None,
#   'columns': [{'name': 'fund_guid', 'type': 'text'},
#    {'name': 'issuer_name', 'type': 'text'},
#    {'name': 'investor_firm_guid', 'type': 'text'},
#    {'name': 'fund_name', 'type': 'text'},
#    {'name': 'vehicle', 'type': 'text'},
#    {'name': 'series_id', 'type': 'text'},
#    {'name': 'cik', 'type': 'text'},
#    {'name': 'fund_url', 'type': 'text'},
#    {'name': 'prospectus_url', 'type': 'text'},
#    {'name': 'prospectus_url_filing_date', 'type': 'Date'},
#    {'name': 'fund_benchmark', 'type': 'text'},
#    {'name': 'fund_management_fee', 'type': 'double'},
#    {'name': 'fund_universe_guid', 'type': 'text'},
#    {'name': 'fund_universe', 'type': 'text'},
#    {'name': 'fund_assets', 'type': 'double'},
#    {'name': 'fund_asset_class', 'type': 'text'},
#    {'name': 'fund_sub_asset_class', 'type': 'text'},
#    {'name': 'fund_assets_date', 'type': 'Date'},
#    {'name': 'inception_year', 'type': 'Integer'},
#    {'name': 'dataset', 'type': 'text'},
#    {'name': 'dataset_id', 'type': 'Integer'}],
#   'filters': ['wide_angle_dataset',
#    'fund_guid',
#    'is_trial',
#    'is_sample',
#    'investor_firm_guid',
#    'fund_universe_guid',
#    'fund_asset_class',
#    'dataset_id'],
#   'primary_key': ['fund_guid'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 6, 14, 25, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '55 00,02,04,06,08,10,12,14,16,18,20,22  * * 1-5',
#    'update_frequency': '55 minutes past midnight, 2am, 4am, 6am, 8am, 10am, noon, 2pm, 4pm, 6pm, 8pm, and 10pm of every Monday through Friday'},
#   'data_version': {'code': '1', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'EVEST/ASF': {'url': ['https://data.nasdaq.com/databases/EVAF'],
#   'vendor_code': 'EVEST',
#   'datatable_code': 'ASF',
#   'name': 'Asset Flows',
#   'description': None,
#   'columns': [{'name': 'product_id', 'type': 'Integer'},
#    {'name': 'product_guid', 'type': 'text'},
#    {'name': 'year', 'type': 'Integer'},
#    {'name': 'month', 'type': 'Integer'},
#    {'name': 'currency', 'type': 'text'},
#    {'name': 'flows_category', 'type': 'text'},
#    {'name': 'flows_category_detail', 'type': 'text'},
#    {'name': 'aum', 'type': 'double'},
#    {'name': 'net_flows', 'type': 'double'}],
#   'filters': ['year',
#    'product_id',
#    'product_guid',
#    'month',
#    'is_trial',
#    'is_sample',
#    'flows_category',
#    'flows_category_detail',
#    'dataset_id'],
#   'primary_key': ['product_id',
#    'product_guid',
#    'year',
#    'month',
#    'flows_category',
#    'flows_category_detail'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 17, 3, 13, 31, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '00 9 * * *',
#    'update_frequency': '9am every day'},
#   'data_version': {'code': '1', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'QUOTEMEDIA/PRICES': {'url': ['https://data.nasdaq.com/databases/EOD'],
#   'vendor_code': 'QUOTEMEDIA',
#   'datatable_code': 'PRICES',
#   'name': 'EOD Prices',
#   'description': None,
#   'columns': [{'name': 'ticker', 'type': 'text'},
#    {'name': 'date', 'type': 'Date'},
#    {'name': 'open', 'type': 'double'},
#    {'name': 'high', 'type': 'double'},
#    {'name': 'low', 'type': 'double'},
#    {'name': 'close', 'type': 'double'},
#    {'name': 'volume', 'type': 'double'},
#    {'name': 'dividend', 'type': 'double'},
#    {'name': 'split', 'type': 'double'},
#    {'name': 'adj_open', 'type': 'double'},
#    {'name': 'adj_high', 'type': 'double'},
#    {'name': 'adj_low', 'type': 'double'},
#    {'name': 'adj_close', 'type': 'double'},
# ...
#    {'name': 'dome_cap_share', 'type': 'BigDecimal(34,12)'},
#    {'name': 'fr_legal_cap_share', 'type': 'BigDecimal(34,12)'},
#    {'name': 'other_spon_share', 'type': 'BigDecimal(34,12)'},
#    {'name': 'change_type', 'type': 'String'},
#    {'name': 'update_time', 'type': 'Date'}],
#   'filters': ['ticker_symbol', 'change_date'],
#   'primary_key': ['ticker_symbol', 'change_date'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 16, 20, 5, 53, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '00 20 * * 1-5',
#    'update_frequency': '8pm every Monday through Friday'},
#   'data_version': {'code': '1', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'DY/EQ1A': {'url': ['https://data.nasdaq.com/databases/DY5'],
#   'vendor_code': 'DY',
#   'datatable_code': 'EQ1A',
#   'name': 'Equity Factor Data Pack 1',
#   'description': None,
#   'columns': [{'name': 'security', 'type': 'text'},
#    {'name': 'exchange', 'type': 'text'},
#    {'name': 'date', 'type': 'Date'},
#    {'name': 'rec', 'type': 'double'},
#    {'name': 'darec', 'type': 'double'},
#    {'name': 'grec', 'type': 'double'},
#    {'name': 'fy12p', 'type': 'double'},
#    {'name': 'darev', 'type': 'double'},
#    {'name': 'grev', 'type': 'double'},
#    {'name': 'sfy12p', 'type': 'double'},
#    {'name': 'dasrev', 'type': 'double'},
#    {'name': 'gsrev', 'type': 'double'},
#    {'name': 'fearng', 'type': 'double'},
#    {'name': 'fsalesg', 'type': 'double'},
#    {'name': 'cashrateofsales', 'type': 'double'},
#    {'name': 'cashtocurrentliability', 'type': 'double'},
#    {'name': 'ctop', 'type': 'double'},
#    {'name': 'ctp5', 'type': 'double'},
#    {'name': 'financingcashgrowrate', 'type': 'double'},
#    {'name': 'investcashgrowrate', 'type': 'double'},
#    {'name': 'nocftooperatingni', 'type': 'double'},
#    {'name': 'opercashgrowrate', 'type': 'double'},
#    {'name': 'opercashintocurrentliability', 'type': 'double'},
#    {'name': 'saleservicecashtoor', 'type': 'double'},
#    {'name': 'cfo2ev', 'type': 'double'},
#    {'name': 'acca', 'type': 'double'},
#    {'name': 'netassetgrowrate', 'type': 'double'},
#    {'name': 'netprofitgrowrate', 'type': 'double'},
#    {'name': 'npparentcompanygrowrate', 'type': 'double'},
#    {'name': 'operatingprofitgrowrate', 'type': 'double'},
#    {'name': 'operatingrevenuegrowrate', 'type': 'double'},
#    {'name': 'totalassetgrowrate', 'type': 'double'},
#    {'name': 'totalprofitgrowrate', 'type': 'double'},
#    {'name': 'degm', 'type': 'double'},
#    {'name': 'earnmom', 'type': 'double'},
#    {'name': 'cmra', 'type': 'double'},
#    {'name': 'ddnbt', 'type': 'double'},
#    {'name': 'ddncr', 'type': 'double'},
#    {'name': 'ddnsr', 'type': 'double'},
#    {'name': 'dvrat', 'type': 'double'},
#    {'name': 'hbeta', 'type': 'double'},
#    {'name': 'hsigma', 'type': 'double'},
#    {'name': 'fiftytwoweekhigh', 'type': 'double'},
#    {'name': 'volatility', 'type': 'double'},
#    {'name': 'skewness', 'type': 'double'},
#    {'name': 'illiquidity', 'type': 'double'},
#    {'name': 'backwardadj', 'type': 'double'},
#    {'name': 'accountspayablestdays', 'type': 'double'},
#    {'name': 'accountspayablestrate', 'type': 'double'},
#    {'name': 'artdays', 'type': 'double'},
#    {'name': 'artrate', 'type': 'double'},
#    {'name': 'currentassetstrate', 'type': 'double'},
#    {'name': 'equitytrate', 'type': 'double'},
#    {'name': 'fixedassetstrate', 'type': 'double'},
#    {'name': 'inventorytdays', 'type': 'double'},
#    {'name': 'inventorytrate', 'type': 'double'},
#    {'name': 'totalassetstrate', 'type': 'double'},
#    {'name': 'rstr12', 'type': 'double'},
#    {'name': 'rstr24', 'type': 'double'},
#    {'name': 'adminiexpenserate', 'type': 'double'},
#    {'name': 'ebittotor', 'type': 'double'},
#    {'name': 'egro', 'type': 'double'},
#    {'name': 'etop', 'type': 'double'},
#    {'name': 'etp5', 'type': 'double'},
#    {'name': 'financialexpenserate', 'type': 'double'},
#    {'name': 'grossincomeratio', 'type': 'double'},
#    {'name': 'netprofitratio', 'type': 'double'},
#    {'name': 'nptotor', 'type': 'double'},
#    {'name': 'operatingexpenserate', 'type': 'double'},
#    {'name': 'operatingprofitratio', 'type': 'double'},
#    {'name': 'operatingprofittotor', 'type': 'double'},
#    {'name': 'roa', 'type': 'double'},
#    {'name': 'roa5', 'type': 'double'},
#    {'name': 'roe', 'type': 'double'},
#    {'name': 'roe5', 'type': 'double'},
#    {'name': 'salescostratio', 'type': 'double'},
#    {'name': 'sue', 'type': 'double'},
#    {'name': 'taxratio', 'type': 'double'},
#    {'name': 'totalprofitcostratio', 'type': 'double'},
#    {'name': 'suoi', 'type': 'double'},
#    {'name': 'dilutedeps', 'type': 'double'},
#    {'name': 'eps', 'type': 'double'},
#    {'name': 'blev', 'type': 'double'},
#    {'name': 'bondspayabletoasset', 'type': 'double'},
#    {'name': 'currentassetsratio', 'type': 'double'},
#    {'name': 'currentratio', 'type': 'double'},
#    {'name': 'debtequityratio', 'type': 'double'},
#    {'name': 'debtsassetratio', 'type': 'double'},
#    {'name': 'equityfixedassetratio', 'type': 'double'},
#    {'name': 'equitytoasset', 'type': 'double'},
#    {'name': 'fixassetratio', 'type': 'double'},
#    {'name': 'intangibleassetratio', 'type': 'double'},
#    {'name': 'longdebttoasset', 'type': 'double'},
#    {'name': 'longdebttoworkingcapital', 'type': 'double'},
#    {'name': 'longtermdebttoasset', 'type': 'double'},
#    {'name': 'mlev', 'type': 'double'},
#    {'name': 'noncurrentassetsratio', 'type': 'double'},
#    {'name': 'quickratio', 'type': 'double'},
#    {'name': 'assi', 'type': 'double'},
#    {'name': 'lcap', 'type': 'double'},
#    {'name': 'lflo', 'type': 'double'},
#    {'name': 'pb', 'type': 'double'},
#    {'name': 'pcf', 'type': 'double'},
#    {'name': 'pe', 'type': 'double'},
#    {'name': 'ps', 'type': 'double'},
#    {'name': 'ta2ev', 'type': 'double'}],
#   'filters': ['date', 'exchange', 'security'],
#   'primary_key': ['security', 'exchange', 'date'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 14, 20, 7, 15, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '00 23 * * 1-5',
#    'update_frequency': '11pm every Monday through Friday'},
#   'data_version': {'code': '2', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'DY/EQ2A': {'url': ['https://data.nasdaq.com/databases/DY5'],
#   'vendor_code': 'DY',
#   'datatable_code': 'EQ2A',
#   'name': 'Equity Factor Data Pack 2',
#   'description': None,
#   'columns': [{'name': 'security', 'type': 'text'},
#    {'name': 'exchange', 'type': 'text'},
#    {'name': 'date', 'type': 'Date'},
#    {'name': 'atr6', 'type': 'double'},
#    {'name': 'bias10', 'type': 'double'},
#    {'name': 'bias20', 'type': 'double'},
#    {'name': 'bias5', 'type': 'double'},
#    {'name': 'bias60', 'type': 'double'},
#    {'name': 'bolldown', 'type': 'double'},
#    {'name': 'bollup', 'type': 'double'},
#    {'name': 'roc6', 'type': 'double'},
#    {'name': 'roc20', 'type': 'double'},
#    {'name': 'dbcd', 'type': 'double'},
#    {'name': 'arc', 'type': 'double'},
#    {'name': 'revs5', 'type': 'double'},
#    {'name': 'revs10', 'type': 'double'},
#    {'name': 'revs20', 'type': 'double'},
#    {'name': 'volumn1m', 'type': 'double'},
#    {'name': 'volumn3m', 'type': 'double'},
#    {'name': 'price1y', 'type': 'double'},
#    {'name': 'ema10', 'type': 'double'},
#    {'name': 'ema12', 'type': 'double'},
#    {'name': 'ema120', 'type': 'double'},
#    {'name': 'ema20', 'type': 'double'},
#    {'name': 'ema26', 'type': 'double'},
#    {'name': 'ema5', 'type': 'double'},
#    {'name': 'ema60', 'type': 'double'},
#    {'name': 'ma120', 'type': 'double'},
#    {'name': 'ma20', 'type': 'double'},
#    {'name': 'ma10', 'type': 'double'},
#    {'name': 'ma5', 'type': 'double'},
#    {'name': 'ma60', 'type': 'double'},
#    {'name': 'apbma', 'type': 'double'},
#    {'name': 'psy', 'type': 'double'},
#    {'name': 'dea', 'type': 'double'},
#    {'name': 'diff', 'type': 'double'},
#    {'name': 'ddi', 'type': 'double'},
#    {'name': 'diz', 'type': 'double'},
#    {'name': 'dif', 'type': 'double'},
#    {'name': 'macd', 'type': 'double'},
#    {'name': 'ma10regresscoeff12', 'type': 'double'},
#    {'name': 'ma10regresscoeff6', 'type': 'double'},
#    {'name': 'dhilo', 'type': 'double'},
#    {'name': 'klingeroscillator', 'type': 'double'},
#    {'name': 'davol10', 'type': 'double'},
#    {'name': 'davol20', 'type': 'double'},
#    {'name': 'davol5', 'type': 'double'},
#    {'name': 'vol10', 'type': 'double'},
#    {'name': 'vol120', 'type': 'double'},
#    {'name': 'vol20', 'type': 'double'},
#    {'name': 'vol240', 'type': 'double'},
#    {'name': 'vol5', 'type': 'double'},
#    {'name': 'vol60', 'type': 'double'},
#    {'name': 'vosc', 'type': 'double'},
#    {'name': 'netnonoitotp', 'type': 'double'},
#    {'name': 'netnonoitotplatest', 'type': 'double'},
#    {'name': 'periodcostsrate', 'type': 'double'},
#    {'name': 'roediluted', 'type': 'double'},
#    {'name': 'roeavg', 'type': 'double'},
#    {'name': 'roeweighted', 'type': 'double'},
#    {'name': 'roecut', 'type': 'double'},
#    {'name': 'roecutweighted', 'type': 'double'},
#    {'name': 'roic', 'type': 'double'},
#    {'name': 'roaebit', 'type': 'double'},
#    {'name': 'roaebitttm', 'type': 'double'},
#    {'name': 'operatingnitotp', 'type': 'double'},
#    {'name': 'operatingnitotplatest', 'type': 'double'},
#    {'name': 'investrassociatestotp', 'type': 'double'},
#    {'name': 'investrassociatestotplatest', 'type': 'double'},
#    {'name': 'npcuttonp', 'type': 'double'},
#    {'name': 'peg3y', 'type': 'double'},
#    {'name': 'peg5y', 'type': 'double'},
#    {'name': 'peindu', 'type': 'double'},
#    {'name': 'pbindu', 'type': 'double'},
#    {'name': 'psindu', 'type': 'double'},
#    {'name': 'pcfindu', 'type': 'double'},
#    {'name': 'pehist120', 'type': 'double'},
#    {'name': 'pehist250', 'type': 'double'},
#    {'name': 'staticpe', 'type': 'double'},
#    {'name': 'forwardpe', 'type': 'double'},
#    {'name': 'teap', 'type': 'double'},
#    {'name': 'niap', 'type': 'double'},
#    {'name': 'variance20', 'type': 'double'},
#    {'name': 'variance60', 'type': 'double'},
#    {'name': 'variance120', 'type': 'double'},
#    {'name': 'kurtosis20', 'type': 'double'},
#    {'name': 'kurtosis60', 'type': 'double'},
#    {'name': 'kurtosis120', 'type': 'double'},
#    {'name': 'alpha20', 'type': 'double'},
#    {'name': 'alpha60', 'type': 'double'},
#    {'name': 'alpha120', 'type': 'double'},
#    {'name': 'beta20', 'type': 'double'},
#    {'name': 'beta60', 'type': 'double'},
#    {'name': 'beta120', 'type': 'double'},
#    {'name': 'sharperatio20', 'type': 'double'},
#    {'name': 'sharperatio60', 'type': 'double'},
#    {'name': 'sharperatio120', 'type': 'double'},
#    {'name': 'treynorratio20', 'type': 'double'},
#    {'name': 'treynorratio60', 'type': 'double'},
#    {'name': 'treynorratio120', 'type': 'double'},
#    {'name': 'informationratio20', 'type': 'double'},
#    {'name': 'informationratio60', 'type': 'double'},
#    {'name': 'informationratio120', 'type': 'double'},
#    {'name': 'gainvariance20', 'type': 'double'},
#    {'name': 'gainvariance60', 'type': 'double'},
#    {'name': 'gainvariance120', 'type': 'double'},
#    {'name': 'lossvariance20', 'type': 'double'},
#    {'name': 'lossvariance60', 'type': 'double'},
#    {'name': 'lossvariance120', 'type': 'double'},
#    {'name': 'gainlossvarianceratio20', 'type': 'double'},
#    {'name': 'gainlossvarianceratio60', 'type': 'double'},
#    {'name': 'gainlossvarianceratio120', 'type': 'double'},
#    {'name': 'realizedvolatility', 'type': 'double'},
#    {'name': 'totalfixedassets', 'type': 'double'},
#    {'name': 'intfreecl', 'type': 'double'},
#    {'name': 'intfreencl', 'type': 'double'},
#    {'name': 'intcl', 'type': 'double'},
#    {'name': 'intdebt', 'type': 'double'},
#    {'name': 'netdebt', 'type': 'double'},
#    {'name': 'nettangibleassets', 'type': 'double'},
#    {'name': 'workingcapital', 'type': 'double'},
#    {'name': 'networkingcapital', 'type': 'double'},
#    {'name': 'totalpaidincapital', 'type': 'double'},
#    {'name': 'retainedearnings', 'type': 'double'},
#    {'name': 'operatenetincome', 'type': 'double'},
#    {'name': 'valuechgprofit', 'type': 'double'},
#    {'name': 'netintexpense', 'type': 'double'},
#    {'name': 'ebit', 'type': 'double'},
#    {'name': 'ebitda', 'type': 'double'},
#    {'name': 'ebiat', 'type': 'double'},
#    {'name': 'nrprofitloss', 'type': 'double'},
#    {'name': 'niapcut', 'type': 'double'},
#    {'name': 'fcff', 'type': 'double'},
#    {'name': 'fcfe', 'type': 'double'},
#    {'name': 'da', 'type': 'double'},
#    {'name': 'trevenuettm', 'type': 'double'},
#    {'name': 'tcostttm', 'type': 'double'},
#    {'name': 'revenuettm', 'type': 'double'},
#    {'name': 'costttm', 'type': 'double'},
#    {'name': 'grossprofitttm', 'type': 'double'},
#    {'name': 'salesexpensettm', 'type': 'double'},
#    {'name': 'adminexpensettm', 'type': 'double'},
#    {'name': 'finanexpensettm', 'type': 'double'},
#    {'name': 'assetimpairlossttm', 'type': 'double'},
#    {'name': 'npfromoperatingttm', 'type': 'double'},
#    {'name': 'npfromvaluechgttm', 'type': 'double'},
#    {'name': 'operateprofitttm', 'type': 'double'},
#    {'name': 'nonoperatingnpttm', 'type': 'double'},
#    {'name': 'tprofitttm', 'type': 'double'},
#    {'name': 'netprofitttm', 'type': 'double'},
#    {'name': 'netprofitapttm', 'type': 'double'},
#    {'name': 'saleservicerendercashttm', 'type': 'double'},
#    {'name': 'netoperatecfttm', 'type': 'double'},
#    {'name': 'netinvestcfttm', 'type': 'double'},
#    {'name': 'netfinancecfttm', 'type': 'double'},
#    {'name': 'grossprofit', 'type': 'double'}],
#   'filters': ['date', 'exchange', 'security'],
#   'primary_key': ['security', 'exchange', 'date'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 14, 20, 21, 6, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '00 23 * * 1-5',
#    'update_frequency': '11pm every Monday through Friday'},
#   'data_version': {'code': '2', 'default': True, 'description': None},
#   'Type': ['Others']},
#  'AS/TRAN': {'url': ['https://data.nasdaq.com/databases/ASTRAN'],
#   'vendor_code': 'AS',
#   'datatable_code': 'TRAN',
#   'name': 'Dow Jones Transportation Average One Minute Bars',
#   'description': None,
#   'columns': [{'name': 'date', 'type': 'Date'},
#    {'name': 'timestamp', 'type': 'text'},
#    {'name': 'ticker', 'type': 'text'},
#    {'name': 'openprice', 'type': 'double'},
#    {'name': 'highprice', 'type': 'double'},
#    {'name': 'lowprice', 'type': 'double'},
#    {'name': 'closeprice', 'type': 'double'},
#    {'name': 'totalvolume', 'type': 'double'},
#    {'name': 'totalquantity', 'type': 'Integer'},
#    {'name': 'totaltradecount', 'type': 'Integer'},
#    {'name': 'year', 'type': 'text'}],
#   'filters': ['ticker', 'timestamp', 'date', 'year'],
#   'primary_key': ['ticker', 'timestamp', 'date'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 15, 10, 7, 36, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '00 11 * * 2-6',
#    'update_frequency': '11am every Tuesday through Saturday'},
#   'data_version': {'code': '2', 'default': True, 'description': None},
#   'Type': ['Prices & Volumes']},
#  'AS/N100': {'url': ['https://data.nasdaq.com/databases/ASN100'],
#   'vendor_code': 'AS',
#   'datatable_code': 'N100',
#   'name': 'Nasdaq 100 One Minute Bars',
#   'description': None,
#   'columns': [{'name': 'date', 'type': 'Date'},
#    {'name': 'timestamp', 'type': 'text'},
#    {'name': 'ticker', 'type': 'text'},
#    {'name': 'openprice', 'type': 'double'},
#    {'name': 'highprice', 'type': 'double'},
#    {'name': 'lowprice', 'type': 'double'},
#    {'name': 'closeprice', 'type': 'double'},
#    {'name': 'totalvolume', 'type': 'double'},
#    {'name': 'totalquantity', 'type': 'Integer'},
#    {'name': 'totaltradecount', 'type': 'Integer'},
#    {'name': 'year', 'type': 'text'}],
#   'filters': ['ticker', 'timestamp', 'date', 'year'],
#   'primary_key': ['ticker', 'timestamp', 'date'],
#   'premium': True,
#   'status': {'refreshed_at': datetime.datetime(2024, 6, 15, 10, 7, 3, tzinfo=tzutc()),
#    'status': 'ON TIME',
#    'expected_at': '00 11 * * 2-6',
#    'update_frequency': '11am every Tuesday through Saturday'},
#   'data_version': {'code': '2', 'default': True, 'description': None},
#   'Type': ['Prices & Volumes']}}

# %%
print('{')
for i in data:
    key = i.strip()
    if value:
        value = i['status']['expected_at'].strip()

    print(f'"{key}" : "{value}",')
print('}')
# Out:
# {
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 for i in data:
#       3     key = i.strip()
# ----> 4     if value:
#       5         value = i['status']['expected_at'].strip()
#       7     print(f'"{key}" : "{value}",')
#
# NameError: name 'value' is not defined

# %%
def get_next_run_time(cron_expression):
    base = datetime.now()
    iter = croniter(cron_expression, base)
    return iter.get_next(datetime)

# %%
# TEST

# %%
# def test_download_data():
#     table = 'QDL/FON'
#     filters = {'date': '2019-10-08', 'contract_code': '967654'}
#     data = download_data(table, **filters)
#     assert not data.empty, "Downloaded data is empty"

# test_download_data()

# %%
def test_save_to_db():
    table = 'QDL/FON'
    filters = {'date': '2019-10-08', 'contract_code': '967654'}
    data = download_data(table, **filters)
    save_to_db(data, 'test_table')
    # Further assertions to verify the data saved to the database

test_save_to_db()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): data.nasdaq.com:443
# DEBUG:urllib3.connectionpool:https://data.nasdaq.com:443 "GET /api/v3/datatables/QDL/FON?date=2019-10-08&contract_code=967654 HTTP/1.1" 200 None
# Data saved to test_table table successfully.

# %%
def test_retrieve_data():
    query = "SELECT * FROM test_table WHERE date='2019-10-08'"
    data = retrieve_data(query)
    assert not data.empty, "Retrieved data is empty"

test_retrieve_data()

# %%
# nd.Database('WIKI').bulk_download_to_file('/data')

# %%
# db = nd.Database('WIKI')
# db.database_code
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): data.nasdaq.com:443
# DEBUG:urllib3.connectionpool:https://data.nasdaq.com:443 "GET /api/v3/databases/WIKI HTTP/1.1" 200 None
# 'WIKI'

# %%
# dt = nd.Datatable('ZACKS/FC')

# %%
# dt.data_fields()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): data.nasdaq.com:443
# DEBUG:urllib3.connectionpool:https://data.nasdaq.com:443 "GET /api/v3/datatables/ZACKS/FC/metadata HTTP/1.1" 200 None
# ['vendor_code',
#  'datatable_code',
#  'name',
#  'description',
#  'columns',
#  'filters',
#  'primary_key',
#  'premium',
#  'status',
#  'data_version']

# %%
# database = nd.Database('WIKI')
# database.data_fields()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): data.nasdaq.com:443
# DEBUG:urllib3.connectionpool:https://data.nasdaq.com:443 "GET /api/v3/databases/WIKI HTTP/1.1" 200 None
# ['id',
#  'name',
#  'database_code',
#  'description',
#  'datasets_count',
#  'downloads',
#  'premium',
#  'image',
#  'favorite',
#  'url_name',
#  'exclusive']

# %%
# databases = nd.Datatable('RATE')
# databases.values
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): data.nasdaq.com:443
# DEBUG:urllib3.connectionpool:https://data.nasdaq.com:443 "GET /api/v3/databases HTTP/1.1" 410 None
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\PycharmProjects\pythonProject\venv\lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File C:\Python310\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File C:\Python310\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File C:\Python310\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# File ~\PycharmProjects\pythonProject\venv\lib\site-packages\nasdaqdatalink\connection.py:90, in Connection.parse(cls, response)
#      89 try:
# ---> 90     return response.json()
#      91 except ValueError:
#
# File ~\PycharmProjects\pythonProject\venv\lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# DataLinkError                             Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 databases = nd.Database.all()
#       2 databases.values
#
# File ~\PycharmProjects\pythonProject\venv\lib\site-packages\nasdaqdatalink\operations\list.py:15, in ListOperation.all(cls, **options)
#      13     options['params'] = {}
#      14 path = Util.constructed_path(cls.list_path(), options['params'])
# ---> 15 r = Connection.request('get', path, **options)
#      16 response_data = r.json()
#      17 Util.convert_to_dates(response_data)
#
# File ~\PycharmProjects\pythonProject\venv\lib\site-packages\nasdaqdatalink\connection.py:40, in Connection.request(cls, http_verb, url, **options)
#      36 options['headers'] = headers
#      38 abs_url = '%s/%s' % (ApiConfig.api_base, url)
# ---> 40 return cls.execute_request(http_verb, abs_url, **options)
#
# File ~\PycharmProjects\pythonProject\venv\lib\site-packages\nasdaqdatalink\connection.py:52, in Connection.execute_request(cls, http_verb, url, **options)
#      47 response = session.request(method=http_verb,
#      48                            url=url,
#      49                            verify=ApiConfig.verify_ssl,
#      50                            **options)
#      51 if response.status_code < 200 or response.status_code >= 300:
# ---> 52     cls.handle_api_error(response)
#      53 else:
#      54     return response
#
# File ~\PycharmProjects\pythonProject\venv\lib\site-packages\nasdaqdatalink\connection.py:96, in Connection.handle_api_error(cls, resp)
#      94 @classmethod
#      95 def handle_api_error(cls, resp):
# ---> 96     error_body = cls.parse(resp)
#      98     # if our app does not form a proper data_link_error response
#      99     # throw generic error
#     100     if 'quandl_error' not in error_body:
#
# File ~\PycharmProjects\pythonProject\venv\lib\site-packages\nasdaqdatalink\connection.py:92, in Connection.parse(cls, response)
#      90     return response.json()
#      91 except ValueError:
# ---> 92     raise DataLinkError(http_status=response.status_code, http_body=response.text)
#
# DataLinkError: (Status 410) Something went wrong. Please try again. If you continue to have problems, please contact us at connect@data.nasdaq.com.
